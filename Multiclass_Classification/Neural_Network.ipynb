# %%
# ============================================================
# Libraries and basic setup
# ============================================================
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from sklearn.feature_selection import mutual_info_classif
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# For Cramér's V
try:
    from scipy.stats import chi2_contingency
    SCIPY_AVAILABLE = True
except ImportError:
    SCIPY_AVAILABLE = False


# Show available files (Kaggle helper)
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# ============================================================
# Reproducibility
# ============================================================
def set_seed(seed: int = 42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# ============================================================
# Feature type declarations (EXPLICIT, not dtype-based)
# ============================================================
# Based on your dataset description
NOMINAL_FEATURES = [
    "identity_code",
    "cultural_background",
    "hobby_engagement_level",
    "creative_expression_index",
]

ORDINAL_FEATURES = [
    "upbringing_influence",
    "external_guidance_usage",
    "support_environment_score",
    "physical_activity_index",
]

NUMERIC_FEATURES = [
    "age_group",
    "focus_intensity",
    "consistency_score",
    # "altruism_score"
]

ID_COLS = ["participant_id"]
DROP_COLS = ["record_code"]
TARGET_COL = "personality_cluster"

ALL_FEATURES = NOMINAL_FEATURES + ORDINAL_FEATURES + NUMERIC_FEATURES

# ============================================================
# Preprocessing
# ============================================================
def preprocess_data(
    train_df: pd.DataFrame,
    test_df: pd.DataFrame,
    target_col: str,
):
    """
    Preprocess train and test:
    - Drop DROP_COLS
    - Impute ordinal/numeric with median (train-based)
    - Impute nominal with most frequent value (train-based)
    """
    train = train_df.copy()
    test = test_df.copy()

    # Drop irrelevant columns
    train.drop(columns=[c for c in DROP_COLS if c in train.columns], inplace=True)
    test.drop(columns=[c for c in DROP_COLS if c in test.columns], inplace=True)

    # Sanity checks
    # for col in ALL_FEATURES:
    #     if col not in train.columns:
    #         raise ValueError(f"Declared feature '{col}' not found in train data.")
    #     if col not in test.columns:
    #         raise ValueError(f"Declared feature '{col}' not found in test data.")

    numeric_like_cols = ORDINAL_FEATURES + NUMERIC_FEATURES
    categorical_cols = NOMINAL_FEATURES

    # Impute numeric-like (ordinal + numeric) with median
    if numeric_like_cols:
        medians = train[numeric_like_cols].median()
        train[numeric_like_cols] = train[numeric_like_cols].fillna(medians)
        for col in numeric_like_cols:
            test[col] = test[col].fillna(medians[col])

    # Impute nominal with most frequent
    if categorical_cols:
        modes = train[categorical_cols].mode().iloc[0]
        for col in categorical_cols:
            mode_val = modes[col]
            train[col] = train[col].fillna(mode_val)
            test[col] = test[col].fillna(mode_val)

    return train, test

# ============================================================
# Feature engineering hook (same for all models)
# ============================================================
def feature_engineering(df: pd.DataFrame) -> pd.DataFrame:
    """
    Feature Engineering Based on Correlation + Mutual Information Insights.
    Uses ONLY correct feature categories (do not mix them).
    """

    eps = 1e-6  # to avoid division by zero

    # -----------------------------------------
    # NEW ENGINEERED FEATURES (ALL NUMERIC)
    # -----------------------------------------

    # A) Nonlinear interactions of top predictors (focus + consistency)
    df["stability_load"] = df["consistency_score"] * df["focus_intensity"]

    # B) Ratio: consistency relative to focus
    df["consistency_focus_ratio"] = df["consistency_score"] / (df["focus_intensity"] + 1)

    # C) Interaction: upbringing × support environment
    df["upbringing_env_interaction"] = (
        df["upbringing_influence"] * df["support_environment_score"]
    )

    # D) Polynomial features
    df["focus_squared"] = df["focus_intensity"] ** 2
    df["consistency_squared"] = df["consistency_score"] ** 2

    # E) Binary indicators (median split)
    df["high_focus"] = (df["focus_intensity"] > df["focus_intensity"].median()).astype(int)
    df["high_consistency"] = (df["consistency_score"] > df["consistency_score"].median()).astype(int)

    # F) Z-scores
    df["focus_z"] = (
        (df["focus_intensity"] - df["focus_intensity"].mean())
        / (df["focus_intensity"].std() + eps)
    )
    df["consistency_z"] = (
        (df["consistency_score"] - df["consistency_score"].mean())
        / (df["consistency_score"].std() + eps)
    )

    return df

# ============================================================
# EDA helpers
# ============================================================
def run_eda(train_df: pd.DataFrame):
    print("\n========== BASIC INFO ==========")
    print(train_df.head())
    print("\nTrain shape:", train_df.shape)
    print("\nTarget distribution:")
    print(train_df[TARGET_COL].value_counts())

    # Plot target distribution
    plt.figure(figsize=(6, 4))
    sns.countplot(x=TARGET_COL, data=train_df)
    plt.title("Target (personality_cluster) Distribution")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Nominal features: countplots vs target
    for col in NOMINAL_FEATURES:
        if col in train_df.columns:
            plt.figure(figsize=(6, 4))
            sns.countplot(x=col, hue=TARGET_COL, data=train_df)
            plt.title(f"Countplot of {col} by {TARGET_COL}")
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()

    # Ordinal & numeric: boxplots vs target
    for col in ORDINAL_FEATURES + NUMERIC_FEATURES:
        if col in train_df.columns:
            plt.figure(figsize=(6, 4))
            sns.boxplot(y=col, data=train_df)
            plt.title(f"Boxplot of {col} by {TARGET_COL}")
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()

    # Correlation heatmap for ordinal/numeric features
    num_cols = ORDINAL_FEATURES + NUMERIC_FEATURES
    if num_cols:
        # Encode target temporarily as numeric for correlation
        le = LabelEncoder()
        y_enc = le.fit_transform(train_df[TARGET_COL])
        corr_df = train_df[num_cols].copy()
        corr_df["_target_enc_"] = y_enc
        corr = corr_df.corr()
        plt.figure(figsize=(8, 6))
        sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
        plt.title("Correlation Heatmap (ordinal/numeric + encoded target)")
        plt.tight_layout()
        plt.show()

# ============================================================
# Feature–target correlation (Cramér’s V + Pearson)
# ============================================================
def compute_feature_target_correlations(
    df: pd.DataFrame,
    target_col: str,
    feature_cols: list,
) -> pd.DataFrame:
    """
    - NOMINAL_FEATURES: Cramér's V with categorical target
    - ORDINAL/NUMERIC: Pearson correlation with encoded target
    """
    results = []

    le_y = LabelEncoder()
    y_encoded = le_y.fit_transform(df[target_col])

    for col in feature_cols:
        series = df[col]
        if col in NOMINAL_FEATURES:
            # Cramér's V
            if SCIPY_AVAILABLE:
                try:
                    contingency = pd.crosstab(series, df[target_col])
                    if contingency.size == 0:
                        v = np.nan
                    else:
                        chi2, _, _, _ = chi2_contingency(contingency)
                        n = contingency.to_numpy().sum()
                        r, k = contingency.shape
                        if n == 0 or min(r, k) <= 1:
                            v = np.nan
                        else:
                            v = np.sqrt((chi2 / n) / (min(k - 1, r - 1)))
                except Exception:
                    v = np.nan
            else:
                v = np.nan

            results.append({
                "feature": col,
                "feature_type": "nominal",
                "metric": "cramers_v",
                "value": v,
            })

        else:
            # Ordinal or numeric: Pearson with encoded target
            try:
                mask = series.notna()
                corr_matrix = np.corrcoef(series[mask], y_encoded[mask])
                corr = corr_matrix[0, 1]
            except Exception:
                corr = np.nan

            results.append({
                "feature": col,
                "feature_type": "ordinal/numeric",
                "metric": "pearson_with_encoded_target",
                "value": corr,
            })

    corr_df = pd.DataFrame(results)
    corr_df.sort_values("value", ascending=False, inplace=True, na_position="last")
    return corr_df

# ============================================================
# Mutual Information (all treated as discrete)
# ============================================================
def compute_mutual_information(
    df: pd.DataFrame,
    target_col: str,
    feature_cols: list,
) -> pd.DataFrame:
    """
    Compute mutual information between each feature and the categorical target.
    - All features are treated as discrete (nominal or ordinal).
    """
    X = df[feature_cols].copy()
    y = df[target_col].copy()

    X_encoded = pd.DataFrame(index=X.index)
    discrete_mask = []

    for col in feature_cols:
        le = LabelEncoder()
        X_encoded[col] = le.fit_transform(X[col].astype(str))
        discrete_mask.append(True)

    y_le = LabelEncoder().fit_transform(y)

    mi_scores = mutual_info_classif(
        X_encoded,
        y_le,
        discrete_features=True,
        random_state=42,
    )

    mi_df = pd.DataFrame({
        "feature": feature_cols,
        "mutual_information": mi_scores,
    }).sort_values("mutual_information", ascending=False)

    return mi_df

# ============================================================
# Shared feature matrix (for SVM, Logistic, NN)
# ============================================================
def build_feature_matrix(
    train_df: pd.DataFrame,
    test_df: pd.DataFrame,
    feature_cols: list,
):
    """
    - One-hot encode NOMINAL_FEATURES
    - Keep ORDINAL/NUMERIC as is (integer/float)
    - Align train/test columns
    - Standard scale everything (logistic/SVM benefit from this)
    """
    X_train_raw = train_df[feature_cols].copy()
    X_test_raw = test_df[feature_cols].copy()

    # One-hot encode only nominal features
    X_train_enc = pd.get_dummies(
        X_train_raw,
        columns=NOMINAL_FEATURES,
        drop_first=False,
    )
    X_test_enc = pd.get_dummies(
        X_test_raw,
        columns=NOMINAL_FEATURES,
        drop_first=False,
    )

    # Align columns
    X_test_enc = X_test_enc.reindex(columns=X_train_enc.columns, fill_value=0)

    feature_names = X_train_enc.columns.tolist()

    # scaler = StandardScaler()
    # X_train_scaled = scaler.fit_transform(X_train_enc.values)
    # X_test_scaled = scaler.transform(X_test_enc.values)

    return X_train_enc.values.astype(float), X_test_enc.values.astype(float), feature_names


# ============================================================
# SVM model
# ============================================================

def train_evaluate_svm(X_train, y_train, X_valid, y_valid):
    """
    SVM with GridSearchCV for hyperparameter tuning.
    Evaluates the best model on the provided validation set.
    """

    param_grid = {
        "C": [0.1, 1, 3, 10],
        "gamma": ["scale", "auto", 0.1, 0.01, 0.001],
        "kernel": ["rbf"],   # rbf works best for nonlinear tabular
    }

    svm = SVC(
        probability=True,
        class_weight="balanced",
        random_state=42,
    )

    grid = GridSearchCV(
        svm,
        param_grid,
        scoring="f1_macro",
        n_jobs=-1,
        cv=3,                    # internal 3-fold CV on training split
        verbose=1,
    )

    print("\n===== Running GridSearch for SVM =====")
    grid.fit(X_train, y_train)

    print("\nBest SVM parameters:", grid.best_params_)
    print("Best CV F1 score:", grid.best_score_)

    # Evaluate on the validation set
    best_svm = grid.best_estimator_
    y_pred = best_svm.predict(X_valid)

    macro_f1 = f1_score(y_valid, y_pred, average="macro")

    print("\n===== Tuned SVM Validation Results =====")
    print(f"Validation Macro F1: {macro_f1:.4f}")
    print("Classification report:")
    print(classification_report(y_valid, y_pred))
    print("Confusion matrix:")
    print(confusion_matrix(y_valid, y_pred))

    return best_svm, macro_f1



# ============================================================
# Logistic Regression model
# ============================================================
def train_evaluate_logreg(X_train, y_train, X_valid, y_valid):
    """
    Logistic Regression with GridSearch hyperparameter tuning.
    Evaluates the best model on the validation set.
    """

    # Base estimator (ignores penalty/solver mismatch errors inside search)
    base_logreg = LogisticRegression(
        multi_class="multinomial",
        max_iter=10000,
        class_weight="balanced",
    )

    param_grid = {
        "C": [0.01, 0.1, 1, 3, 10],
        "solver": ["lbfgs", "saga"],     # saga supports l1/l2
        "penalty": ["l2"],               # multinomial + saga/lbfgs require L2
    }

    grid = GridSearchCV(
        base_logreg,
        param_grid,
        scoring="f1_macro",
        cv=3,
        verbose=1,
        n_jobs=-1,
    )

    print("\n===== Running GridSearch for Logistic Regression =====")
    grid.fit(X_train, y_train)

    print("\nBest LogReg parameters:", grid.best_params_)
    print("Best CV Macro F1:", grid.best_score_)

    # Evaluate on validation split
    best_logreg = grid.best_estimator_
    y_pred = best_logreg.predict(X_valid)
    macro_f1 = f1_score(y_valid, y_pred, average="macro")

    print("\n===== Tuned Logistic Regression Validation Results =====")
    print(f"Validation Macro F1 (LogReg): {macro_f1:.4f}")
    print("Classification report (LogReg):")
    print(classification_report(y_valid, y_pred))
    print("Confusion matrix (LogReg):")
    print(confusion_matrix(y_valid, y_pred))

    return best_logreg, macro_f1


# ============================================================
# PyTorch NN model
# ============================================================
class TabularNN(nn.Module):
    def __init__(self, input_dim: int, num_classes: int, hidden_dims=(128, 64), dropout=0.2):
        super().__init__()
        layers = []
        prev_dim = input_dim
        for h in hidden_dims:
            layers.append(nn.Linear(prev_dim, h))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))
            prev_dim = h
        layers.append(nn.Linear(prev_dim, num_classes))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)


def train_evaluate_nn(
    X_train,
    y_train,
    X_valid,
    y_valid,
    num_classes: int,
    epochs: int = 50,
    batch_size: int = 256,
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    X_train_t = torch.tensor(X_train, dtype=torch.float32)
    y_train_t = torch.tensor(y_train, dtype=torch.long)
    X_valid_t = torch.tensor(X_valid, dtype=torch.float32)
    y_valid_t = torch.tensor(y_valid, dtype=torch.long)

    train_ds = TensorDataset(X_train_t, y_train_t)
    valid_ds = TensorDataset(X_valid_t, y_valid_t)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_ds, batch_size=batch_size, shuffle=False)

    model = TabularNN(input_dim=X_train.shape[1], num_classes=num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val_f1 = -np.inf
    best_state = None
    patience = 10
    patience_counter = 0

    for epoch in range(1, epochs + 1):
        # Train
        model.train()
        total_loss = 0.0
        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            optimizer.zero_grad()
            logits = model(xb)
            loss = criterion(logits, yb)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * xb.size(0)

        avg_train_loss = total_loss / len(train_loader.dataset)

        # Validate
        model.eval()
        all_preds = []
        all_true = []
        val_loss = 0.0
        with torch.no_grad():
            for xb, yb in valid_loader:
                xb = xb.to(device)
                yb = yb.to(device)
                logits = model(xb)
                loss = criterion(logits, yb)
                val_loss += loss.item() * xb.size(0)

                preds = torch.argmax(logits, dim=1)
                all_preds.append(preds.cpu().numpy())
                all_true.append(yb.cpu().numpy())

        all_preds = np.concatenate(all_preds)
        all_true = np.concatenate(all_true)
        avg_val_loss = val_loss / len(valid_loader.dataset)
        val_f1 = f1_score(all_true, all_preds, average="macro")

        print(
            f"Epoch {epoch:03d} | Train Loss: {avg_train_loss:.4f} "
            f"| Val Loss: {avg_val_loss:.4f} | Val Macro F1: {val_f1:.4f}"
        )

        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    print("\n===== NN Validation Results =====")
    print(f"Best Macro F1 (NN): {best_val_f1:.4f}")
    model.eval()
    with torch.no_grad():
        logits = model(X_valid_t.to(device))
        preds = torch.argmax(logits, dim=1).cpu().numpy()
    print("Classification report (NN):")
    print(classification_report(y_valid, preds))
    print("Confusion matrix (NN):")
    print(confusion_matrix(y_valid, preds))

    return model, best_val_f1


def nn_predict(model: nn.Module, X: np.ndarray) -> np.ndarray:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    X_t = torch.tensor(X, dtype=torch.float32).to(device)
    with torch.no_grad():
        logits = model(X_t)
        preds = torch.argmax(logits, dim=1).cpu().numpy()
    return preds

def tune_and_train_nn(
    X_train,
    y_train,
    X_valid,
    y_valid,
    num_classes,
):
    search_space = [
        {"hidden_dims": (128, 64), "dropout": 0.2, "lr": 1e-3, "weight_decay": 1e-4},
        {"hidden_dims": (256, 128), "dropout": 0.3, "lr": 5e-4, "weight_decay": 1e-5},
        {"hidden_dims": (64, 32), "dropout": 0.1, "lr": 1e-3, "weight_decay": 1e-4},
        {"hidden_dims": (128, 128), "dropout": 0.4, "lr": 1e-4, "weight_decay": 1e-4},
    ]

    best_f1 = -np.inf
    best_model = None
    best_params = None

    for params in search_space:
        print("\nTrying params:", params)

        model, val_f1 = train_evaluate_nn(
            X_train=X_train,
            y_train=y_train,
            X_valid=X_valid,
            y_valid=y_valid,
            num_classes=num_classes,
            epochs=60,
            batch_size=256,
            lr=params["lr"],
            weight_decay=params["weight_decay"],
        )

        if val_f1 > best_f1:
            best_f1 = val_f1
            best_model = model
            best_params = params

    print("\n===== Best NN Hyperparameters =====")
    print(best_params)
    print("Best Validation Macro F1:", best_f1)

    return best_model, best_f1



# ============================================================
# Main
# ============================================================
def main():
    set_seed(42)

    train_path = "/kaggle/input/multidimensional-personality-cluster-prediction/train.csv"
    test_path = "/kaggle/input/multidimensional-personality-cluster-prediction/test.csv"

    if not os.path.exists(train_path):
        raise FileNotFoundError(f"Could not find {train_path}")
    if not os.path.exists(test_path):
        raise FileNotFoundError(f"Could not find {test_path}")

    print(f"Loading data from {train_path} and {test_path} ...")
    train_df = pd.read_csv(train_path)
    test_df = pd.read_csv(test_path)

    # Preprocess
    print("\n========== Preprocessing ==========")
    train_proc, test_proc = preprocess_data(
        train_df=train_df,
        test_df=test_df,
        target_col=TARGET_COL,
    )

    NUMERIC_FEATURES = [
        "age_group",
        "focus_intensity",
        "consistency_score",
    
        # ENGINEERED FEATURES
        # "stability_load",
        # "consistency_focus_ratio",
        # "upbringing_env_interaction",
    ]
    ALL_FEATURES = NOMINAL_FEATURES + ORDINAL_FEATURES + NUMERIC_FEATURES
    # Feature engineering
    print("\n========== Feature Engineering ==========")
    train_fe = feature_engineering(train_proc.copy())
    test_fe = feature_engineering(test_proc.copy())

    # EDA
    print("\n========== EDA ==========")
    run_eda(train_fe)

    # Feature analysis: correlations
    print("\n========== Feature–Target Correlation Analysis ==========")
    corr_df = compute_feature_target_correlations(
        df=train_fe,
        target_col=TARGET_COL,
        feature_cols=ALL_FEATURES,
    )
    print(corr_df)

    # Mutual Information
    print("\n========== Mutual Information Analysis ==========")
    mi_df = compute_mutual_information(
        df=train_fe,
        target_col=TARGET_COL,
        feature_cols=ALL_FEATURES,
    )
    print(mi_df)

    # Encode target
    y = train_fe[TARGET_COL].values
    le_target = LabelEncoder()
    y_enc = le_target.fit_transform(y)
    num_classes = len(le_target.classes_)
    print(f"\nTarget classes ({num_classes}): {list(le_target.classes_)}")

    # Build shared feature matrix
    print("\n========== Building Feature Matrix (shared for all models) ==========")
    X_all, X_test_all, encoded_feature_names = build_feature_matrix(
        train_df=train_fe,
        test_df=test_fe,
        feature_cols=ALL_FEATURES,
    )
    print(f"Encoded feature dimension: {X_all.shape[1]}")

    # Train/validation split
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_all,
        y_enc,
        test_size=0.2,
        random_state=42,
        stratify=y_enc,
    )

    # Train & evaluate SVM
    svm_model, svm_f1 = train_evaluate_svm(X_tr, y_tr, X_val, y_val)

    # Train & evaluate Logistic Regression
    logreg_model, logreg_f1 = train_evaluate_logreg(X_tr, y_tr, X_val, y_val)

    # Train & evaluate NN
    nn_model, nn_f1 = tune_and_train_nn(
        X_tr,
        y_tr,
        X_val,
        y_val,
        num_classes=num_classes
    )

    # Model comparison
    print("\n========== Model Comparison ==========")
    print(f"SVM   Macro F1: {svm_f1:.4f}")
    print(f"LogReg Macro F1: {logreg_f1:.4f}")
    print(f"NN    Macro F1: {nn_f1:.4f}")

    scores = {
        "svm": svm_f1,
        "logreg": logreg_f1,
        "nn": nn_f1,
    }
    best_model_name = max(scores, key=scores.get)
    print(f"Selected model: {best_model_name.upper()}")

    # best_model_name = "svm"
    # IMPORTANT: Use validation-trained model directly (NO full retrain → avoids overfitting)
    print("\n========== Using Validation-Trained Model for Final Predictions ==========")

    if best_model_name == "svm":
        final_model = svm_model
        test_pred_enc = final_model.predict(X_test_all)

    elif best_model_name == "logreg":
        final_model = logreg_model
        test_pred_enc = final_model.predict(X_test_all)

    else:
        final_model = nn_model
        test_pred_enc = nn_predict(final_model, X_test_all)

    # Decode predictions and write submission
    test_pred_labels = le_target.inverse_transform(test_pred_enc)
    if "participant_id" not in test_df.columns:
        raise ValueError("Expected 'participant_id' column in test.csv for submission.")

    submission = pd.DataFrame({
        "participant_id": test_df["participant_id"],
        "personality_cluster": test_pred_labels,
    })
    submission.to_csv("submission.csv", index=False)
    print("\nSubmission file written to submission.csv")
    print("Done.")


if __name__ == "__main__":
    main()
# Out:
# /kaggle/input/multidimensional-personality-cluster-prediction/sample_submission.csv
# /kaggle/input/multidimensional-personality-cluster-prediction/train.csv
# /kaggle/input/multidimensional-personality-cluster-prediction/test.csv
# Loading data from /kaggle/input/multidimensional-personality-cluster-prediction/train.csv and /kaggle/input/multidimensional-personality-cluster-prediction/test.csv ...
#
# ========== Preprocessing ==========
#
# ========== Feature Engineering ==========
#
# ========== EDA ==========
#
# ========== BASIC INFO ==========
#    participant_id  age_group  identity_code  cultural_background  \
# 0             643         18              1                    0
# 1            1753         16              1                    3
# 2            1402         17              0                    2
# 3            2033         17              1                    0
# 4             991         16              0                    0
#
#    upbringing_influence  focus_intensity  consistency_score  \
# 0                     4        18.118879                 24
# 1                     2         2.469271                 19
# 2                     3         3.456401                 25
# 3                     1        15.838131                 25
# 4                     0         1.045373                 19
#
#    external_guidance_usage  support_environment_score  hobby_engagement_level  \
# 0                        1                          0                       1
# 1                        0                          1                       0
# 2                        0                          0                       0
# 3                        1                          2                       0
# 4                        1                          2                       0
#
#    ...  personality_cluster  stability_load  consistency_focus_ratio  \
# 0  ...            Cluster_E      434.853105                 1.255304
# 1  ...            Cluster_E       46.916158                 5.476654
# 2  ...            Cluster_E       86.410026                 5.609908
# 3  ...            Cluster_E      395.953269                 1.484725
# 4  ...            Cluster_E       19.862094                 9.289258
#
#   upbringing_env_interaction  focus_squared  consistency_squared  high_focus  \
# 0                          0     328.293789                  576           1
# 1                          2       6.097302                  361           0
# 2                          0      11.946708                  625           0
# 3                          2     250.846386                  625           1
# 4                          0       1.092805                  361           0
#
#    high_consistency   focus_z  consistency_z
# 0                 1  1.467774       1.105626
# 1                 1 -1.276439       0.516374
# 2                 1 -1.103343       1.223477
# 3                 1  1.067837       1.223477
# 4                 1 -1.526125       0.516374
#
# [5 rows x 23 columns]
#
# Train shape: (1913, 23)
#
# Target distribution:
# personality_cluster
# Cluster_E    974
# Cluster_D    328
# Cluster_C    306
# Cluster_B    220
# Cluster_A     85
# Name: count, dtype: int64
# ========== Feature–Target Correlation Analysis ==========
#                       feature     feature_type                       metric  \
# 10          consistency_score  ordinal/numeric  pearson_with_encoded_target
# 2      hobby_engagement_level          nominal                    cramers_v
# 3   creative_expression_index          nominal                    cramers_v
# 0               identity_code          nominal                    cramers_v
# 4        upbringing_influence  ordinal/numeric  pearson_with_encoded_target
# 1         cultural_background          nominal                    cramers_v
# 8                   age_group  ordinal/numeric  pearson_with_encoded_target
# 7     physical_activity_index  ordinal/numeric  pearson_with_encoded_target
# 5     external_guidance_usage  ordinal/numeric  pearson_with_encoded_target
# 6   support_environment_score  ordinal/numeric  pearson_with_encoded_target
# 9             focus_intensity  ordinal/numeric  pearson_with_encoded_target
#
#        value
# 10  0.726062
# 2   0.080171
# 3   0.077008
# 0   0.054988
# 4   0.044331
# 1   0.044108
# 8  -0.004767
# 7  -0.031018
# 5  -0.111259
# 6  -0.125621
# 9  -0.138321
#
# ========== Mutual Information Analysis ==========
#                       feature  mutual_information
# 9             focus_intensity            1.326295
# 10          consistency_score            0.516039
# 6   support_environment_score            0.015340
# 5     external_guidance_usage            0.007973
# 4        upbringing_influence            0.004657
# 8                   age_group            0.003618
# 2      hobby_engagement_level            0.003171
# 1         cultural_background            0.002808
# 3   creative_expression_index            0.002791
# 0               identity_code            0.001520
# 7     physical_activity_index            0.001478
#
# Target classes (5): ['Cluster_A', 'Cluster_B', 'Cluster_C', 'Cluster_D', 'Cluster_E']
#
# ========== Building Feature Matrix (shared for all models) ==========
# Encoded feature dimension: 17
#
# ===== Running GridSearch for SVM =====
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
#
# Best SVM parameters: {'C': 3, 'gamma': 0.01, 'kernel': 'rbf'}
# Best CV F1 score: 0.5869968153522854
#
# ===== Tuned SVM Validation Results =====
# Validation Macro F1: 0.6065
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.41      0.42        17
#            1       0.56      0.43      0.49        44
#            2       0.60      0.54      0.57        61
#            3       0.57      0.77      0.65        66
#            4       0.91      0.88      0.90       195
#
#     accuracy                           0.74       383
#    macro avg       0.62      0.61      0.61       383
# weighted avg       0.74      0.74      0.74       383
#
# Confusion matrix:
# [[  7   5   1   1   3]
#  [  6  19  11   2   6]
#  [  3   8  33  15   2]
#  [  0   1   9  51   5]
#  [  0   1   1  21 172]]
#
# ===== Running GridSearch for Logistic Regression =====
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#
# Best LogReg parameters: {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# Best CV Macro F1: 0.46382540119975796
#
# ===== Tuned Logistic Regression Validation Results =====
# Validation Macro F1 (LogReg): 0.4780
# Classification report (LogReg):
#               precision    recall  f1-score   support
#
#            0       0.16      0.41      0.23        17
#            1       0.38      0.34      0.36        44
#            2       0.42      0.34      0.38        61
#            3       0.51      0.56      0.54        66
#            4       0.93      0.85      0.88       195
#
#     accuracy                           0.64       383
#    macro avg       0.48      0.50      0.48       383
# weighted avg       0.68      0.64      0.65       383
#
# Confusion matrix (LogReg):
# [[  7   6   0   1   3]
#  [ 12  15  10   4   3]
#  [ 16  17  21   5   2]
#  [  6   2  16  37   5]
#  [  2   0   3  25 165]]
#
# Trying params: {'hidden_dims': (128, 64), 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001}
# Epoch 001 | Train Loss: 1.4647 | Val Loss: 1.1691 | Val Macro F1: 0.1349
# Epoch 002 | Train Loss: 1.1635 | Val Loss: 1.0669 | Val Macro F1: 0.1480
# Epoch 003 | Train Loss: 1.0535 | Val Loss: 0.9577 | Val Macro F1: 0.2721
# Epoch 004 | Train Loss: 0.9910 | Val Loss: 0.9077 | Val Macro F1: 0.3804
# Epoch 005 | Train Loss: 0.9402 | Val Loss: 0.8802 | Val Macro F1: 0.3994
# Epoch 006 | Train Loss: 0.9292 | Val Loss: 0.8622 | Val Macro F1: 0.4218
# Epoch 007 | Train Loss: 0.9009 | Val Loss: 0.8444 | Val Macro F1: 0.4781
# Epoch 008 | Train Loss: 0.8904 | Val Loss: 0.8350 | Val Macro F1: 0.4817
# Epoch 009 | Train Loss: 0.8865 | Val Loss: 0.8277 | Val Macro F1: 0.4546
# Epoch 010 | Train Loss: 0.8776 | Val Loss: 0.8160 | Val Macro F1: 0.4843
# Epoch 011 | Train Loss: 0.8538 | Val Loss: 0.8072 | Val Macro F1: 0.4598
# Epoch 012 | Train Loss: 0.8502 | Val Loss: 0.8000 | Val Macro F1: 0.4659
# Epoch 013 | Train Loss: 0.8528 | Val Loss: 0.7917 | Val Macro F1: 0.4824
# Epoch 014 | Train Loss: 0.8312 | Val Loss: 0.7819 | Val Macro F1: 0.4700
# Epoch 015 | Train Loss: 0.8358 | Val Loss: 0.7755 | Val Macro F1: 0.4678
# Epoch 016 | Train Loss: 0.8239 | Val Loss: 0.7687 | Val Macro F1: 0.4695
# Epoch 017 | Train Loss: 0.8206 | Val Loss: 0.7616 | Val Macro F1: 0.4677
# Epoch 018 | Train Loss: 0.8193 | Val Loss: 0.7608 | Val Macro F1: 0.4780
# Epoch 019 | Train Loss: 0.8099 | Val Loss: 0.7528 | Val Macro F1: 0.4968
# Epoch 020 | Train Loss: 0.8090 | Val Loss: 0.7537 | Val Macro F1: 0.4675
# Epoch 021 | Train Loss: 0.8102 | Val Loss: 0.7480 | Val Macro F1: 0.4744
# Epoch 022 | Train Loss: 0.8034 | Val Loss: 0.7459 | Val Macro F1: 0.4799
# Epoch 023 | Train Loss: 0.8000 | Val Loss: 0.7427 | Val Macro F1: 0.4787
# Epoch 024 | Train Loss: 0.7756 | Val Loss: 0.7368 | Val Macro F1: 0.4815
# Epoch 025 | Train Loss: 0.7842 | Val Loss: 0.7323 | Val Macro F1: 0.4917
# Epoch 026 | Train Loss: 0.7823 | Val Loss: 0.7305 | Val Macro F1: 0.4793
# Epoch 027 | Train Loss: 0.7902 | Val Loss: 0.7242 | Val Macro F1: 0.4934
# Epoch 028 | Train Loss: 0.7752 | Val Loss: 0.7226 | Val Macro F1: 0.5013
# Epoch 029 | Train Loss: 0.7696 | Val Loss: 0.7211 | Val Macro F1: 0.4960
# Epoch 030 | Train Loss: 0.7644 | Val Loss: 0.7212 | Val Macro F1: 0.4932
# Epoch 031 | Train Loss: 0.7616 | Val Loss: 0.7155 | Val Macro F1: 0.5102
# Epoch 032 | Train Loss: 0.7600 | Val Loss: 0.7181 | Val Macro F1: 0.4944
# Epoch 033 | Train Loss: 0.7515 | Val Loss: 0.7095 | Val Macro F1: 0.5173
# Epoch 034 | Train Loss: 0.7505 | Val Loss: 0.7106 | Val Macro F1: 0.5044
# Epoch 035 | Train Loss: 0.7426 | Val Loss: 0.7061 | Val Macro F1: 0.5122
# Epoch 036 | Train Loss: 0.7479 | Val Loss: 0.7057 | Val Macro F1: 0.5279
# Epoch 037 | Train Loss: 0.7481 | Val Loss: 0.7063 | Val Macro F1: 0.5067
# Epoch 038 | Train Loss: 0.7534 | Val Loss: 0.7056 | Val Macro F1: 0.5080
# Epoch 039 | Train Loss: 0.7420 | Val Loss: 0.7045 | Val Macro F1: 0.5344
# Epoch 040 | Train Loss: 0.7383 | Val Loss: 0.7000 | Val Macro F1: 0.5256
# Epoch 041 | Train Loss: 0.7428 | Val Loss: 0.6993 | Val Macro F1: 0.5342
# Epoch 042 | Train Loss: 0.7419 | Val Loss: 0.6979 | Val Macro F1: 0.5219
# Epoch 043 | Train Loss: 0.7281 | Val Loss: 0.6959 | Val Macro F1: 0.5394
# Epoch 044 | Train Loss: 0.7301 | Val Loss: 0.6980 | Val Macro F1: 0.5135
# Epoch 045 | Train Loss: 0.7160 | Val Loss: 0.6933 | Val Macro F1: 0.5512
# Epoch 046 | Train Loss: 0.7310 | Val Loss: 0.6923 | Val Macro F1: 0.5808
# Epoch 047 | Train Loss: 0.7239 | Val Loss: 0.6959 | Val Macro F1: 0.5295
# Epoch 048 | Train Loss: 0.7233 | Val Loss: 0.6909 | Val Macro F1: 0.5574
# Epoch 049 | Train Loss: 0.7204 | Val Loss: 0.6913 | Val Macro F1: 0.5961
# Epoch 050 | Train Loss: 0.7121 | Val Loss: 0.6890 | Val Macro F1: 0.5924
# Epoch 051 | Train Loss: 0.7197 | Val Loss: 0.6882 | Val Macro F1: 0.6145
# Epoch 052 | Train Loss: 0.7008 | Val Loss: 0.6904 | Val Macro F1: 0.6017
# Epoch 053 | Train Loss: 0.6952 | Val Loss: 0.6889 | Val Macro F1: 0.6278
# Epoch 054 | Train Loss: 0.6993 | Val Loss: 0.6873 | Val Macro F1: 0.5964
# Epoch 055 | Train Loss: 0.6964 | Val Loss: 0.6854 | Val Macro F1: 0.5815
# Epoch 056 | Train Loss: 0.7049 | Val Loss: 0.6866 | Val Macro F1: 0.6360
# Epoch 057 | Train Loss: 0.7033 | Val Loss: 0.6840 | Val Macro F1: 0.6311
# Epoch 058 | Train Loss: 0.6955 | Val Loss: 0.6877 | Val Macro F1: 0.6115
# Epoch 059 | Train Loss: 0.7158 | Val Loss: 0.6843 | Val Macro F1: 0.6283
# Epoch 060 | Train Loss: 0.7011 | Val Loss: 0.6846 | Val Macro F1: 0.6291
#
# ===== NN Validation Results =====
# Best Macro F1 (NN): 0.6360
# Classification report (NN):
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.45        17
#            1       0.56      0.57      0.56        44
#            2       0.63      0.52      0.57        61
#            3       0.59      0.71      0.65        66
#            4       0.89      0.93      0.91       195
#
#     accuracy                           0.76       383
#    macro avg       0.73      0.61      0.63       383
# weighted avg       0.76      0.76      0.75       383
#
# Confusion matrix (NN):
# [[  5   7   1   1   3]
#  [  0  25  12   2   5]
#  [  0  11  32  16   2]
#  [  0   1   6  47  12]
#  [  0   1   0  13 181]]
#
# Trying params: {'hidden_dims': (256, 128), 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 1e-05}
# Epoch 001 | Train Loss: 1.4311 | Val Loss: 1.1673 | Val Macro F1: 0.1349
# Epoch 002 | Train Loss: 1.2139 | Val Loss: 1.0715 | Val Macro F1: 0.1595
# Epoch 003 | Train Loss: 1.1281 | Val Loss: 0.9914 | Val Macro F1: 0.2562
# Epoch 004 | Train Loss: 1.0693 | Val Loss: 0.9439 | Val Macro F1: 0.3258
# Epoch 005 | Train Loss: 1.0149 | Val Loss: 0.9127 | Val Macro F1: 0.3255
# Epoch 006 | Train Loss: 0.9996 | Val Loss: 0.8934 | Val Macro F1: 0.3428
# Epoch 007 | Train Loss: 0.9720 | Val Loss: 0.8787 | Val Macro F1: 0.3730
# Epoch 008 | Train Loss: 0.9610 | Val Loss: 0.8698 | Val Macro F1: 0.3833
# Epoch 009 | Train Loss: 0.9463 | Val Loss: 0.8624 | Val Macro F1: 0.4198
# Epoch 010 | Train Loss: 0.9460 | Val Loss: 0.8575 | Val Macro F1: 0.4182
# Epoch 011 | Train Loss: 0.9219 | Val Loss: 0.8524 | Val Macro F1: 0.4321
# Epoch 012 | Train Loss: 0.9110 | Val Loss: 0.8463 | Val Macro F1: 0.4551
# Epoch 013 | Train Loss: 0.9132 | Val Loss: 0.8413 | Val Macro F1: 0.4614
# Epoch 014 | Train Loss: 0.9130 | Val Loss: 0.8380 | Val Macro F1: 0.4498
# Epoch 015 | Train Loss: 0.8931 | Val Loss: 0.8320 | Val Macro F1: 0.4797
# Epoch 016 | Train Loss: 0.8952 | Val Loss: 0.8265 | Val Macro F1: 0.4571
# Epoch 017 | Train Loss: 0.8830 | Val Loss: 0.8217 | Val Macro F1: 0.4571
# Epoch 018 | Train Loss: 0.8914 | Val Loss: 0.8166 | Val Macro F1: 0.4542
# Epoch 019 | Train Loss: 0.8660 | Val Loss: 0.8111 | Val Macro F1: 0.4662
# Epoch 020 | Train Loss: 0.8610 | Val Loss: 0.8055 | Val Macro F1: 0.4730
# Epoch 021 | Train Loss: 0.8636 | Val Loss: 0.8005 | Val Macro F1: 0.4839
# Epoch 022 | Train Loss: 0.8578 | Val Loss: 0.7969 | Val Macro F1: 0.4712
# Epoch 023 | Train Loss: 0.8680 | Val Loss: 0.7943 | Val Macro F1: 0.4648
# Epoch 024 | Train Loss: 0.8521 | Val Loss: 0.7900 | Val Macro F1: 0.4756
# Epoch 025 | Train Loss: 0.8506 | Val Loss: 0.7880 | Val Macro F1: 0.4724
# Epoch 026 | Train Loss: 0.8400 | Val Loss: 0.7833 | Val Macro F1: 0.4790
# Epoch 027 | Train Loss: 0.8305 | Val Loss: 0.7795 | Val Macro F1: 0.4852
# Epoch 028 | Train Loss: 0.8427 | Val Loss: 0.7770 | Val Macro F1: 0.4749
# Epoch 029 | Train Loss: 0.8291 | Val Loss: 0.7743 | Val Macro F1: 0.4637
# Epoch 030 | Train Loss: 0.8146 | Val Loss: 0.7709 | Val Macro F1: 0.4594
# Epoch 031 | Train Loss: 0.8106 | Val Loss: 0.7673 | Val Macro F1: 0.4943
# Epoch 032 | Train Loss: 0.8115 | Val Loss: 0.7630 | Val Macro F1: 0.4913
# Epoch 033 | Train Loss: 0.8162 | Val Loss: 0.7604 | Val Macro F1: 0.4930
# Epoch 034 | Train Loss: 0.8126 | Val Loss: 0.7591 | Val Macro F1: 0.4700
# Epoch 035 | Train Loss: 0.8136 | Val Loss: 0.7572 | Val Macro F1: 0.4791
# Epoch 036 | Train Loss: 0.8164 | Val Loss: 0.7533 | Val Macro F1: 0.4695
# Epoch 037 | Train Loss: 0.7977 | Val Loss: 0.7516 | Val Macro F1: 0.4695
# Epoch 038 | Train Loss: 0.8046 | Val Loss: 0.7497 | Val Macro F1: 0.4825
# Epoch 039 | Train Loss: 0.7965 | Val Loss: 0.7484 | Val Macro F1: 0.4924
# Epoch 040 | Train Loss: 0.7915 | Val Loss: 0.7447 | Val Macro F1: 0.4885
# Epoch 041 | Train Loss: 0.7988 | Val Loss: 0.7432 | Val Macro F1: 0.4752
# Early stopping triggered.
#
# ===== NN Validation Results =====
# Best Macro F1 (NN): 0.4943
# Classification report (NN):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        17
#            1       0.39      0.39      0.39        44
#            2       0.50      0.48      0.49        61
#            3       0.58      0.62      0.60        66
#            4       0.87      0.94      0.90       195
#
#     accuracy                           0.70       383
#    macro avg       0.47      0.48      0.48       383
# weighted avg       0.67      0.70      0.69       383
#
# Confusion matrix (NN):
# [[  0  12   1   1   3]
#  [  0  17  19   2   6]
#  [  0  13  29  17   2]
#  [  0   1   8  41  16]
#  [  0   1   1  10 183]]
#
# Trying params: {'hidden_dims': (64, 32), 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}
# Epoch 001 | Train Loss: 1.6044 | Val Loss: 1.2377 | Val Macro F1: 0.1349
# Epoch 002 | Train Loss: 1.2182 | Val Loss: 1.0982 | Val Macro F1: 0.1527
# Epoch 003 | Train Loss: 1.0977 | Val Loss: 0.9787 | Val Macro F1: 0.2873
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 004 | Train Loss: 1.0043 | Val Loss: 0.9127 | Val Macro F1: 0.3832
# Epoch 005 | Train Loss: 0.9609 | Val Loss: 0.8778 | Val Macro F1: 0.3860
# Epoch 006 | Train Loss: 0.9411 | Val Loss: 0.8634 | Val Macro F1: 0.4361
# Epoch 007 | Train Loss: 0.9171 | Val Loss: 0.8537 | Val Macro F1: 0.4679
# Epoch 008 | Train Loss: 0.9162 | Val Loss: 0.8448 | Val Macro F1: 0.4558
# Epoch 009 | Train Loss: 0.9068 | Val Loss: 0.8321 | Val Macro F1: 0.4741
# Epoch 010 | Train Loss: 0.8875 | Val Loss: 0.8233 | Val Macro F1: 0.4599
# Epoch 011 | Train Loss: 0.8742 | Val Loss: 0.8171 | Val Macro F1: 0.4586
# Epoch 012 | Train Loss: 0.8679 | Val Loss: 0.8098 | Val Macro F1: 0.4659
# Epoch 013 | Train Loss: 0.8694 | Val Loss: 0.8015 | Val Macro F1: 0.4678
# Epoch 014 | Train Loss: 0.8439 | Val Loss: 0.7922 | Val Macro F1: 0.4701
# Epoch 015 | Train Loss: 0.8449 | Val Loss: 0.7859 | Val Macro F1: 0.4531
# Epoch 016 | Train Loss: 0.8408 | Val Loss: 0.7780 | Val Macro F1: 0.4631
# Epoch 017 | Train Loss: 0.8144 | Val Loss: 0.7733 | Val Macro F1: 0.4610
# Epoch 018 | Train Loss: 0.8272 | Val Loss: 0.7675 | Val Macro F1: 0.4698
# Epoch 019 | Train Loss: 0.8117 | Val Loss: 0.7612 | Val Macro F1: 0.4686
# Early stopping triggered.
#
# ===== NN Validation Results =====
# Best Macro F1 (NN): 0.4741
# Classification report (NN):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        17
#            1       0.38      0.36      0.37        44
#            2       0.50      0.49      0.50        61
#            3       0.56      0.59      0.57        66
#            4       0.87      0.94      0.90       195
#
#     accuracy                           0.70       383
#    macro avg       0.46      0.48      0.47       383
# weighted avg       0.66      0.70      0.68       383
#
# Confusion matrix (NN):
# [[  0  12   1   1   3]
#  [  0  16  20   2   6]
#  [  0  12  30  17   2]
#  [  0   1   9  39  17]
#  [  0   1   0  11 183]]
#
# Trying params: {'hidden_dims': (128, 128), 'dropout': 0.4, 'lr': 0.0001, 'weight_decay': 0.0001}
# Epoch 001 | Train Loss: 1.5740 | Val Loss: 1.4500 | Val Macro F1: 0.2219
# Epoch 002 | Train Loss: 1.4618 | Val Loss: 1.3518 | Val Macro F1: 0.1986
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 003 | Train Loss: 1.3771 | Val Loss: 1.2776 | Val Macro F1: 0.1574
# Epoch 004 | Train Loss: 1.3089 | Val Loss: 1.2229 | Val Macro F1: 0.1349
# Epoch 005 | Train Loss: 1.2622 | Val Loss: 1.1835 | Val Macro F1: 0.1349
# Epoch 006 | Train Loss: 1.2297 | Val Loss: 1.1532 | Val Macro F1: 0.1442
# Epoch 007 | Train Loss: 1.2111 | Val Loss: 1.1272 | Val Macro F1: 0.1664
# Epoch 008 | Train Loss: 1.1875 | Val Loss: 1.1032 | Val Macro F1: 0.1903
# Epoch 009 | Train Loss: 1.1503 | Val Loss: 1.0807 | Val Macro F1: 0.2049
# Epoch 010 | Train Loss: 1.1301 | Val Loss: 1.0592 | Val Macro F1: 0.2261
# Epoch 011 | Train Loss: 1.1172 | Val Loss: 1.0391 | Val Macro F1: 0.2309
# Epoch 012 | Train Loss: 1.1079 | Val Loss: 1.0216 | Val Macro F1: 0.2354
# Epoch 013 | Train Loss: 1.1005 | Val Loss: 1.0049 | Val Macro F1: 0.2545
# Epoch 014 | Train Loss: 1.0817 | Val Loss: 0.9908 | Val Macro F1: 0.2537
# Epoch 015 | Train Loss: 1.0650 | Val Loss: 0.9779 | Val Macro F1: 0.2768
# Epoch 016 | Train Loss: 1.0586 | Val Loss: 0.9663 | Val Macro F1: 0.2843
# Epoch 017 | Train Loss: 1.0381 | Val Loss: 0.9553 | Val Macro F1: 0.2820
# Epoch 018 | Train Loss: 1.0226 | Val Loss: 0.9451 | Val Macro F1: 0.2925
# Epoch 019 | Train Loss: 1.0015 | Val Loss: 0.9362 | Val Macro F1: 0.2987
# Epoch 020 | Train Loss: 1.0014 | Val Loss: 0.9281 | Val Macro F1: 0.3152
# Epoch 021 | Train Loss: 1.0054 | Val Loss: 0.9211 | Val Macro F1: 0.3252
# Epoch 022 | Train Loss: 1.0072 | Val Loss: 0.9145 | Val Macro F1: 0.3578
# Epoch 023 | Train Loss: 0.9839 | Val Loss: 0.9093 | Val Macro F1: 0.3549
# Epoch 024 | Train Loss: 0.9951 | Val Loss: 0.9046 | Val Macro F1: 0.3575
# Epoch 025 | Train Loss: 0.9762 | Val Loss: 0.9000 | Val Macro F1: 0.3615
# Epoch 026 | Train Loss: 0.9730 | Val Loss: 0.8965 | Val Macro F1: 0.3572
# Epoch 027 | Train Loss: 0.9624 | Val Loss: 0.8924 | Val Macro F1: 0.3598
# Epoch 028 | Train Loss: 0.9627 | Val Loss: 0.8890 | Val Macro F1: 0.3625
# Epoch 029 | Train Loss: 0.9585 | Val Loss: 0.8858 | Val Macro F1: 0.3684
# Epoch 030 | Train Loss: 0.9609 | Val Loss: 0.8826 | Val Macro F1: 0.3757
# Epoch 031 | Train Loss: 0.9690 | Val Loss: 0.8795 | Val Macro F1: 0.3790
# Epoch 032 | Train Loss: 0.9582 | Val Loss: 0.8770 | Val Macro F1: 0.3808
# Epoch 033 | Train Loss: 0.9552 | Val Loss: 0.8749 | Val Macro F1: 0.3808
# Epoch 034 | Train Loss: 0.9505 | Val Loss: 0.8732 | Val Macro F1: 0.3784
# Epoch 035 | Train Loss: 0.9514 | Val Loss: 0.8716 | Val Macro F1: 0.3933
# Epoch 036 | Train Loss: 0.9429 | Val Loss: 0.8695 | Val Macro F1: 0.3902
# Epoch 037 | Train Loss: 0.9388 | Val Loss: 0.8670 | Val Macro F1: 0.3921
# Epoch 038 | Train Loss: 0.9369 | Val Loss: 0.8650 | Val Macro F1: 0.3984
# Epoch 039 | Train Loss: 0.9359 | Val Loss: 0.8630 | Val Macro F1: 0.4044
# Epoch 040 | Train Loss: 0.9272 | Val Loss: 0.8610 | Val Macro F1: 0.4168
# Epoch 041 | Train Loss: 0.9388 | Val Loss: 0.8591 | Val Macro F1: 0.4106
# Epoch 042 | Train Loss: 0.9066 | Val Loss: 0.8574 | Val Macro F1: 0.4095
# Epoch 043 | Train Loss: 0.9186 | Val Loss: 0.8554 | Val Macro F1: 0.4207
# Epoch 044 | Train Loss: 0.9223 | Val Loss: 0.8538 | Val Macro F1: 0.4175
# Epoch 045 | Train Loss: 0.9180 | Val Loss: 0.8523 | Val Macro F1: 0.4286
# Epoch 046 | Train Loss: 0.9135 | Val Loss: 0.8511 | Val Macro F1: 0.4378
# Epoch 047 | Train Loss: 0.9043 | Val Loss: 0.8498 | Val Macro F1: 0.4435
# Epoch 048 | Train Loss: 0.9071 | Val Loss: 0.8480 | Val Macro F1: 0.4497
# Epoch 049 | Train Loss: 0.9333 | Val Loss: 0.8469 | Val Macro F1: 0.4497
# Epoch 050 | Train Loss: 0.9173 | Val Loss: 0.8452 | Val Macro F1: 0.4553
# Epoch 051 | Train Loss: 0.9169 | Val Loss: 0.8441 | Val Macro F1: 0.4525
# Epoch 052 | Train Loss: 0.8997 | Val Loss: 0.8427 | Val Macro F1: 0.4586
# Epoch 053 | Train Loss: 0.9107 | Val Loss: 0.8415 | Val Macro F1: 0.4559
# Epoch 054 | Train Loss: 0.9088 | Val Loss: 0.8401 | Val Macro F1: 0.4539
# Epoch 055 | Train Loss: 0.8970 | Val Loss: 0.8392 | Val Macro F1: 0.4551
# Epoch 056 | Train Loss: 0.8936 | Val Loss: 0.8379 | Val Macro F1: 0.4642
# Epoch 057 | Train Loss: 0.9001 | Val Loss: 0.8366 | Val Macro F1: 0.4602
# Epoch 058 | Train Loss: 0.8918 | Val Loss: 0.8361 | Val Macro F1: 0.4607
# Epoch 059 | Train Loss: 0.9001 | Val Loss: 0.8353 | Val Macro F1: 0.4607
# Epoch 060 | Train Loss: 0.9059 | Val Loss: 0.8340 | Val Macro F1: 0.4602
#
# ===== NN Validation Results =====
# Best Macro F1 (NN): 0.4642
# Classification report (NN):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        17
#            1       0.39      0.39      0.39        44
#            2       0.47      0.44      0.46        61
#            3       0.58      0.53      0.56        66
#            4       0.85      0.96      0.90       195
#
#     accuracy                           0.70       383
#    macro avg       0.46      0.46      0.46       383
# weighted avg       0.65      0.70      0.67       383
#
# Confusion matrix (NN):
# [[  0  12   1   1   3]
#  [  0  17  19   1   7]
#  [  0  12  27  18   4]
#  [  0   2   9  35  20]
#  [  0   1   1   5 188]]
#
# ===== Best NN Hyperparameters =====
# {'hidden_dims': (128, 64), 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001}
# Best Validation Macro F1: 0.6359833797233858
#
# ========== Model Comparison ==========
# SVM   Macro F1: 0.6065
# LogReg Macro F1: 0.4780
# NN    Macro F1: 0.6360
# Selected model: NN
#
# ========== Using Validation-Trained Model for Final Predictions ==========
#
# Submission file written to submission.csv
# Done.
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
